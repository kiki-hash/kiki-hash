# %% [markdown]
# <a href="https://colab.research.google.com/github/kiki-hash/kiki-hash/blob/main/NASCAR_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries

import pandas as pd
from google.colab import drive
import chardet
import openpyxl

# mounts the Google Drive
#drive.mount('/content/drive')

# %%
# Open the file in Google Drive
with open('/content/drive/MyDrive/Cup_drivers_averages.csv', 'rb') as f:
    result = chardet.detect(f.read()) # or readline if the file is large
print(result)
# Out:
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}

# %%
df = pd.read_csv('/content/drive/MyDrive/Cup_drivers_averages.csv', encoding='utf-8', index_col=0, header=1)
df.head()
# Out:
#              Driver  Wins  Avg\nFinish  Races  Top\n5's  Top\n10's  Top\n20's  \
# 1     William Byron    10         13.2     79        22         36         61
# 2       Kyle Larson     8         14.1     79        31         40         58
# 3      Denny Hamlin     7         13.7     79        26         38         58
# 4  Christopher Bell     6         13.3     79        25         44         59
# 5     Chase Elliott     5         12.7     72        20         37         58
#
#   Laps\nLed  Avg\nStart  DNF
# 1     1,824        11.4    8
# 2     2,130         9.2   15
# 3     1,914        11.5    8
# 4     1,291        10.2    9
# 5     1,075        13.2    5

# %%
import http.client

import json
import requests
import pandas as pd

api_key = 'c589497e64ef4741b46862634a704356'
url = 'https://api.sportsdata.io/nascar/v2/json/drivers?key=c589497e64ef4741b46862634a704356'

headers = {'Content-Type': 'application/json',
           'ocp-apim-subscription-key': 'c589497e64ef4741b46862634a704356'}

response = requests.get(url, headers=headers)

print(response.status_code)
# Out:
# 200

# %%
df = pd.DataFrame(response.json())
df.head()
# Out:
#    DriverID FirstName  LastName  Number NumberDisplay  Team BirthDate  \
# 0  80000696   Michele    Abbate    30.0            30  None      None
# 1  80000544   Jeffrey     Abbey    44.0            44  None      None
# 2  80000386      Rico     Abreu    89.0          None  None      None
# 3  80000473   Michael  Affarano     3.0          None  None      None
# 4  80000678   Lawless      Alan    45.0            45  None      None
#
#   BirthPlace Gender  Height  Weight Manufacturer     Engine    Chassis  \
# 0       None   None     NaN     NaN         None       None       None
# 1       None   None     NaN     NaN         None       None       None
# 2       None   None     NaN     NaN         None       None       None
# 3       None   None     NaN     NaN    Chevrolet  Chevrolet  Chevrolet
# 4       None   None     NaN     NaN         None       None       None
#
#              Sponsors CrewChief  \
# 0                None      None
# 1                None      None
# ...

# %%
df.to_csv('drivers.csv')

# %% [markdown]
# # New Section
